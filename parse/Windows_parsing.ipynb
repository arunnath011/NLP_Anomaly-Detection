# %%
import sys
sys.path.append('../')

import os
import pandas as pd
import re
import numpy as np
from logparser import Spell, Drain
from tqdm import tqdm
#from logdeep.dataset.session import sliding_window
import glob
tqdm.pandas()
pd.options.mode.chained_assignment = None  # default='warn'


# In the first column of the log, "-" indicates non-alert messages while others are alert messages.
def count_anomaly(log_path):
    total_size = 0
    normal_size = 0
    with open(log_path, errors='ignore') as f:
        for line in f:
            total_size += 1
            if line.split('')[0] == '-':
                normal_size += 1
    print("total size {}, abnormal size {}".format(total_size, total_size - normal_size))


def deeplog_file_generator(filename, df, features):
    with open(filename, 'w') as f:
        for _, row in df.iterrows():
            for val in zip(*row[features]):
                f.write(','.join([str(v) for v in val]) + ' ')
            f.write('\n')




def sample_raw_data(data_file, output_file, sample_window_size, sample_step_size):
    # sample 1M by sliding window, abnormal rate is over 2%
    sample_data = []
    labels = []
    idx = 0

    # spirit dataset can start from the 2Mth line, as there are many abnormal lines gathering in the first 2M
    with open(data_file, 'r', errors='ignore') as f:
        for line in f:
            labels.append(line.split()[0] != '-')
            sample_data.append(line)

            if len(labels) == sample_window_size:
                abnormal_rate = sum(np.array(labels)) / len(labels)
                print(f"{idx + 1} lines, abnormal rate {abnormal_rate}")
                break

            idx += 1
            if idx % sample_step_size == 0:
                print(f"Process {round(idx/sample_window_size * 100,4)} % raw data", end='\r')

    with open(output_file, "w") as f:
        f.writelines(sample_data)

    print("Sampling done")

# %%
def parse_log(input_dir, output_dir, log_file, parser_type):
    #log_format = '<Label> <Id> <Date> <Admin> <Month> <Day> <Time> <AdminAddr> <Content>'
    log_format = '<Date> <Time>, <Type>             <Admin>  <Content>'
    regex = [
        r'(0x)[0-9a-fA-F]+',  # hexadecimal
        r'\d+\.\d+\.\d+\.\d+',
        r'(?<=Warning: we failed to resolve data source name )[\w\s]+',
        r'\d+'
    ]
    keep_para = False
    if parser_type == "drain":
        # the hyper parameter is set according to http://jmzhu.logpai.com/pub/pjhe_icws2017.pdf
        st = 0.3  # Similarity threshold
        depth = 3  # Depth of all leaf nodes

        # Drain is modified
        parser = Drain.LogParser(log_format,
                                 indir=input_dir,
                                 outdir=output_dir,
                                 depth=depth,
                                 st=st,
                                 rex=regex,
                                 keep_para=keep_para, maxChild=1000)
        parser.parse(log_file)

    elif parser_type == "spell":
        tau = 0.35
        parser = Spell.LogParser(indir=data_dir,
                                 outdir=output_dir,
                                 log_format=log_format,
                                 tau=tau,
                                 rex=regex,
                                 keep_para=keep_para)
        parser.parse(log_file)

# %%
##File parser

data_dir = os.path.expanduser("../dataset/Windows")
output_dir = "../output/windows/"
raw_log_file = "xaa.txt"
sample_log_file = "xaa.txt"
sample_window_size = 2*10**7
sample_step_size = 10**4
window_name = ''
log_file = sample_log_file

parser_type = 'drain'
#mins
window_size = 1
step_size = 0.5
train_ratio = 6000

hresult_dict = {'0x00000000': 1,'0x800f080d':2,'0x800f0805':3, '0x80070490':4, '0x80004005':5, '0x80070001':6, '0x80071a2d':7, '0x80070216':8, '0x80070bc2':9, '0x800f0816':10, '0x800f0806':11, '0x800f0902':12, '0x80070002':13}

def matchfunc(line):
    # Capture one-or-more characters of non-whitespace after the initial match
    match = re.search(r'HRESULT = (\S+)', line)

    # Did we find a match?
    if match:
        # Yes, process it
        weather = match.group(1)
        return(hresult_dict[weather])
    return(0)

########
# count anomaly
########
# count_anomaly(data_dir + log_file)
# sys.exit()

import glob
file_list = glob.glob(data_dir +"/*.txt")
#########
# sample raw data
#########
#sample_raw_data(data_dir+raw_log_file, data_dir+sample_log_file, sample_window_size, sample_step_size )

a = glob.glob(data_dir +"/*.*") 
file_list=[os.path.basename(list_item) for list_item in a]
print(file_list)
##########
# Parser #
#########
for file in file_list:
    print("\nParsing", file)
    parse_log(data_dir, output_dir, file, parser_type)
# Out:
# ['wrd9632.txt', 'wrd9037.txt', 'wrd9700.txt', 'wrd9765.txt', 'wrd990156.txt', 'wrd990056.txt', 'wrd9451.txt', 'wrd9888.txt', 'wrd9656.txt', 'wrd9773.txt', 'wrd9541.txt', 'wrd9391.txt', 'wrd9841.txt', 'wrd9624.txt', 'wrd9117.txt', 'wrd990146.txt', 'wrd9335.txt', 'wrd990111.txt', 'wrd9251.txt', 'wrd9333.txt', 'wrd9158.txt', 'wrd990124.txt', 'wrd990060.txt', 'wrd9696.txt', 'wrd9567.txt', 'wrd02.txt', 'wrd59.txt', 'wrd9775.txt', 'wrd9481.txt', 'wrd9655.txt', 'wrd9606.txt', 'wrd9644.txt', 'wrd9326.txt', 'wrd9076.txt', 'wrd9460.txt', 'wrd9004.txt', 'wrd9790.txt', 'wrd9488.txt', 'wrd9548.txt', 'wrd9538.txt', 'wrd9679.txt', 'wrd9307.txt', 'wrd9837.txt', 'wrd9890.txt', 'wrd9688.txt', 'wrd03.txt', 'wrd9099.txt', 'wrd9337.txt', 'wrd9583.txt', 'wrd70.txt', 'wrd9025.txt', 'wrd9534.txt', 'wrd9370.txt', 'wrd990140.txt', 'wrd9755.txt', 'wrd990006.txt', 'wrd9240.txt', 'wrd990017.txt', 'wrd9636.txt', 'wrd9769.txt', 'wrd9631.txt', 'wrd9448.txt', 'wrd9554.txt', 'wrd9148.txt', 'wrd9342.txt', 'wrd9133.txt', 'wrd990138.txt', 'wrd9759.txt', 'wrd9066.txt', 'wrd990034.txt', 'wrd9835.txt', 'wrd9077.txt', 'wrd9139.txt', 'wrd990030.txt', 'wrd86.txt', 'wrd9866.txt', 'wrd9234.txt', 'wrd9290.txt', 'wrd9415.txt', 'wrd20.txt', 'wrd9857.txt', 'wrd9891.txt', 'wrd81.txt', 'wrd9382.txt', 'wrd9264.txt', 'wrd9800.txt', 'wrd9727.txt', 'wrd9288.txt', 'wrd9674.txt', 'wrd14.txt', 'wrd9054.txt', 'wrd9005.txt', 'wrd9411.txt', 'wrd9689.txt', 'wrd42.txt', 'wrd9831.txt', 'wrd9717.txt', 'wrd9475.txt', 'wrd9885.txt', 'wrd990002.txt', 'wrd9096.txt', 'wrd9128.txt', 'wrd9074.txt', 'wrd9537.txt', 'wrd9744.txt', 'wrd9884.txt', 'wrd990008.txt', 'wrd9112.txt', 'wrd9495.txt', 'wrd990057.txt', 'wrd9364.txt', 'wrd9439.txt', 'wrd990007.txt', 'wrd990076.txt', 'wrd9786.txt', 'wrd9704.txt', 'wrd9513.txt', 'wrd9204.txt', 'wrd9875.txt', 'wrd990093.txt', 'wrd9016.txt', 'wrd9599.txt', 'wrd990061.txt', 'wrd990054.txt', 'wrd9277.txt', 'wrd9898.txt', 'wrd9407.txt', 'wrd9654.txt', 'wrd9157.txt', 'wrd9834.txt', 'wrd9887.txt', 'wrd9758.txt', 'wrd9331.txt', 'wrd990015.txt', 'wrd9080.txt', 'wrd9262.txt', 'wrd9202.txt', 'wrd9867.txt', 'wrd9237.txt', 'wrd9570.txt', 'wrd9176.txt', 'wrd9477.txt', 'wrd9889.txt', 'wrd9788.txt', 'wrd9255.txt', 'wrd990049.txt', 'wrd9231.txt', 'wrd9356.txt', 'wrd21.txt', 'wrd9057.txt', 'wrd9079.txt', 'wrd53.txt', 'wrd9521.txt', 'wrd9850.txt', 'wrd9097.txt', 'wrd9336.txt', 'wrd9530.txt', 'wrd9067.txt', 'wrd9585.txt', 'wrd9125.txt', 'wrd990000.txt', 'wrd83.txt', 'wrd9785.txt', 'wrd9185.txt', 'wrd00.txt', 'wrd9648.txt', 'wrd9504.txt', 'wrd9522.txt', 'wrd9236.txt', 'wrd9684.txt', 'wrd9216.txt', 'wrd9113.txt', 'wrd9101.txt', 'wrd9730.txt', 'wrd9317.txt', 'wrd9552.txt', 'wrd9677.txt', 'wrd9322.txt', 'wrd990088.txt', 'wrd22.txt', 'wrd9894.txt', 'wrd9852.txt', 'wrd9652.txt', 'wrd9036.txt', 'wrd990131.txt', 'wrd9069.txt', 'wrd9014.txt', 'wrd69.txt', 'wrd9316.txt', 'wrd9359.txt', 'wrd9804.txt', 'wrd9000.txt', 'wrd9388.txt', 'wrd9410.txt', 'wrd990094.txt', 'wrd9738.txt', 'wrd9130.txt', 'wrd9345.txt', 'wrd9728.txt', 'wrd9737.txt', 'wrd9864.txt', 'wrd9486.txt', 'wrd67.txt', 'wrd9291.txt', 'wrd9428.txt', 'wrd9011.txt', 'wrd9273.txt', 'wrd9401.txt', 'wrd9555.txt', 'wrd9123.txt', 'wrd9086.txt', 'wrd9718.txt', 'wrd9848.txt', 'wrd9620.txt', 'wrd9365.txt', 'wrd9200.txt', 'wrd9229.txt', 'wrd9899.txt', 'wrd990090.txt', 'wrd87.txt', 'wrd9551.txt', 'wrd9116.txt', 'wrd9210.txt', 'wrd9681.txt', 'wrd9089.txt', 'wrd66.txt', 'wrd9735.txt', 'wrd9284.txt', 'wrd9576.txt', 'wrd9799.txt', 'wrd9653.txt', 'wrd9485.txt', 'wrd01.txt', 'wrd990086.txt', 'wrd9062.txt', 'wrd9154.txt', 'wrd9060.txt', 'wrd9206.txt', 'wrd990100.txt', 'wrd76.txt', 'wrd9318.txt', 'wrd9269.txt', 'wrd9827.txt', 'wrd990075.txt', 'wrd9296.txt', 'wrd9751.txt', 'wrd9690.txt', 'wrd9104.txt', 'wrd78.txt', 'wrd9373.txt', 'wrd990082.txt', 'wrd9849.txt', 'wrd9061.txt', 'wrd9547.txt', 'wrd9761.txt', 'wrd9274.txt', 'wrd9397.txt', 'wrd9708.txt', 'wrd9353.txt', 'wrd9452.txt', 'wrd9607.txt', 'wrd9760.txt', 'wrd9367.txt', 'wrd36.txt', 'wrd9306.txt', 'wrd98 ...
#
# Parsing wrd9632.txt
# Parsing file: ../dataset/Windows/wrd9632.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:10.066822]
#
# Parsing wrd9037.txt
# Parsing file: ../dataset/Windows/wrd9037.txt
# Total size after encoding is 99645 100000
# Parsing done. [Time taken: 0:00:10.641708]
#
# Parsing wrd9700.txt
# Parsing file: ../dataset/Windows/wrd9700.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:10.700493]
#
# Parsing wrd9765.txt
# Parsing file: ../dataset/Windows/wrd9765.txt
# Total size after encoding is 99985 100000
# Parsing done. [Time taken: 0:00:10.475468]
#
# Parsing wrd990156.txt
# Parsing file: ../dataset/Windows/wrd990156.txt
# Total size after encoding is 8384 8388
# Parsing done. [Time taken: 0:00:00.752175]
#
# Parsing wrd990056.txt
# Parsing file: ../dataset/Windows/wrd990056.txt
# Total size after encoding is 99953 100000
# Parsing done. [Time taken: 0:00:10.211905]
#
# Parsing wrd9451.txt
# Parsing file: ../dataset/Windows/wrd9451.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:10.251246]
#
# Parsing wrd9888.txt
# Parsing file: ../dataset/Windows/wrd9888.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:10.323954]
#
# Parsing wrd9656.txt
# Parsing file: ../dataset/Windows/wrd9656.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:10.167609]
#
# Parsing wrd9773.txt
# Parsing file: ../dataset/Windows/wrd9773.txt
# Total size after encoding is 99988 100000
# Parsing done. [Time taken: 0:00:10.440115]
#
# Parsing wrd9541.txt
# Parsing file: ../dataset/Windows/wrd9541.txt
# Total size after encoding is 99981 100000
# Parsing done. [Time taken: 0:00:10.260664]
#
# Parsing wrd9391.txt
# Parsing file: ../dataset/Windows/wrd9391.txt
# Total size after encoding is 99967 100000
# Parsing done. [Time taken: 0:00:10.140127]
#
# Parsing wrd9841.txt
# Parsing file: ../dataset/Windows/wrd9841.txt
# Total size after encoding is 99990 100000
# Parsing done. [Time taken: 0:00:15.085261]
#
# Parsing wrd9624.txt
# Parsing file: ../dataset/Windows/wrd9624.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:21.427657]
#
# Parsing wrd9117.txt
# Parsing file: ../dataset/Windows/wrd9117.txt
# Total size after encoding is 99222 100000
# Parsing done. [Time taken: 0:00:21.248244]
#
# Parsing wrd990146.txt
# Parsing file: ../dataset/Windows/wrd990146.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:21.742197]
#
# Parsing wrd9335.txt
# Parsing file: ../dataset/Windows/wrd9335.txt
# Total size after encoding is 99989 100000
# Parsing done. [Time taken: 0:00:21.425478]
#
# Parsing wrd990111.txt
# Parsing file: ../dataset/Windows/wrd990111.txt
# Total size after encoding is 99967 100000
# Parsing done. [Time taken: 0:00:21.003459]
#
# Parsing wrd9251.txt
# Parsing file: ../dataset/Windows/wrd9251.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:20.994730]
#
# Parsing wrd9333.txt
# Parsing file: ../dataset/Windows/wrd9333.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:21.237992]
#
# Parsing wrd9158.txt
# Parsing file: ../dataset/Windows/wrd9158.txt
# Total size after encoding is 99947 100000
# Parsing done. [Time taken: 0:00:21.211593]
#
# Parsing wrd990124.txt
# Parsing file: ../dataset/Windows/wrd990124.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:20.911700]
#
# Parsing wrd990060.txt
# Parsing file: ../dataset/Windows/wrd990060.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:21.215368]
#
# Parsing wrd9696.txt
# Parsing file: ../dataset/Windows/wrd9696.txt
# Total size after encoding is 99615 100000
# Parsing done. [Time taken: 0:00:22.547166]
#
# Parsing wrd9567.txt
# Parsing file: ../dataset/Windows/wrd9567.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.451406]
#
# Parsing wrd02.txt
# Parsing file: ../dataset/Windows/wrd02.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:21.195081]
#
# Parsing wrd59.txt
# Parsing file: ../dataset/Windows/wrd59.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:21.011496]
#
# Parsing wrd9775.txt
# Parsing file: ../dataset/Windows/wrd9775.txt
# Total size after encoding is 99991 100000
# Parsing done. [Time taken: 0:00:21.248078]
#
# Parsing wrd9481.txt
# Parsing file: ../dataset/Windows/wrd9481.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:21.072250]
#
# Parsing wrd9655.txt
# Parsing file: ../dataset/Windows/wrd9655.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:20.830356]
#
# Parsing wrd9606.txt
# Parsing file: ../dataset/Windows/wrd9606.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:21.637573]
#
# Parsing wrd9644.txt
# Parsing file: ../dataset/Windows/wrd9644.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:20.970101]
#
# Parsing wrd9326.txt
# Parsing file: ../dataset/Windows/wrd9326.txt
# Total size after encoding is 99974 100000
# Parsing done. [Time taken: 0:00:20.993878]
#
# Parsing wrd9076.txt
# Parsing file: ../dataset/Windows/wrd9076.txt
# Total size after encoding is 99985 100000
# Parsing done. [Time taken: 0:00:21.473994]
#
# Parsing wrd9460.txt
# Parsing file: ../dataset/Windows/wrd9460.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:20.796029]
#
# Parsing wrd9004.txt
# Parsing file: ../dataset/Windows/wrd9004.txt
# Total size after encoding is 99953 100000
# Parsing done. [Time taken: 0:00:20.538791]
#
# Parsing wrd9790.txt
# Parsing file: ../dataset/Windows/wrd9790.txt
# Total size after encoding is 99960 100000
# Parsing done. [Time taken: 0:00:21.422204]
#
# Parsing wrd9488.txt
# Parsing file: ../dataset/Windows/wrd9488.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:21.067900]
#
# Parsing wrd9548.txt
# Parsing file: ../dataset/Windows/wrd9548.txt
# Total size after encoding is 99912 100000
# Parsing done. [Time taken: 0:00:21.315393]
#
# Parsing wrd9538.txt
# Parsing file: ../dataset/Windows/wrd9538.txt
# Total size after encoding is 99995 100000
# Parsing done. [Time taken: 0:00:21.417021]
#
# Parsing wrd9679.txt
# Parsing file: ../dataset/Windows/wrd9679.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:20.984577]
#
# Parsing wrd9307.txt
# Parsing file: ../dataset/Windows/wrd9307.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:20.988091]
#
# Parsing wrd9837.txt
# Parsing file: ../dataset/Windows/wrd9837.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:21.212146]
#
# Parsing wrd9890.txt
# Parsing file: ../dataset/Windows/wrd9890.txt
# Total size after encoding is 99959 100000
# Parsing done. [Time taken: 0:00:20.941359]
#
# Parsing wrd9688.txt
# Parsing file: ../dataset/Windows/wrd9688.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:21.230614]
#
# Parsing wrd03.txt
# Parsing file: ../dataset/Windows/wrd03.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:20.722766]
#
# Parsing wrd9099.txt
# Parsing file: ../dataset/Windows/wrd9099.txt
# Total size after encoding is 99952 100000
# Parsing done. [Time taken: 0:00:21.202785]
#
# Parsing wrd9337.txt
# Parsing file: ../dataset/Windows/wrd9337.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:21.237669]
#
# Parsing wrd9583.txt
# Parsing file: ../dataset/Windows/wrd9583.txt
# Total size after encoding is 99991 100000
# Parsing done. [Time taken: 0:00:20.761123]
#
# Parsing wrd70.txt
# Parsing file: ../dataset/Windows/wrd70.txt
# Total size after encoding is 99874 100000
# Parsing done. [Time taken: 0:00:21.416628]
#
# Parsing wrd9025.txt
# Parsing file: ../dataset/Windows/wrd9025.txt
# Total size after encoding is 99920 100000
# Parsing done. [Time taken: 0:00:21.975012]
#
# Parsing wrd9534.txt
# Parsing file: ../dataset/Windows/wrd9534.txt
# Total size after encoding is 99986 100000
# Parsing done. [Time taken: 0:00:20.720301]
#
# Parsing wrd9370.txt
# Parsing file: ../dataset/Windows/wrd9370.txt
# Total size after encoding is 99974 100000
# Parsing done. [Time taken: 0:00:20.723228]
#
# Parsing wrd990140.txt
# Parsing file: ../dataset/Windows/wrd990140.txt
# Total size after encoding is 99971 100000
# Parsing done. [Time taken: 0:00:21.033241]
#
# Parsing wrd9755.txt
# Parsing file: ../dataset/Windows/wrd9755.txt
# Total size after encoding is 99990 100000
# Parsing done. [Time taken: 0:00:20.938704]
#
# Parsing wrd990006.txt
# Parsing file: ../dataset/Windows/wrd990006.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:20.979997]
#
# Parsing wrd9240.txt
# Parsing file: ../dataset/Windows/wrd9240.txt
# Total size after encoding is 99952 100000
# Parsing done. [Time taken: 0:00:21.497518]
#
# Parsing wrd990017.txt
# Parsing file: ../dataset/Windows/wrd990017.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:20.965599]
#
# Parsing wrd9636.txt
# Parsing file: ../dataset/Windows/wrd9636.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.254285]
#
# Parsing wrd9769.txt
# Parsing file: ../dataset/Windows/wrd9769.txt
# Total size after encoding is 99947 100000
# Parsing done. [Time taken: 0:00:21.454619]
#
# Parsing wrd9631.txt
# Parsing file: ../dataset/Windows/wrd9631.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.420246]
#
# Parsing wrd9448.txt
# Parsing file: ../dataset/Windows/wrd9448.txt
# Total size after encoding is 99915 100000
# Parsing done. [Time taken: 0:00:20.524096]
#
# Parsing wrd9554.txt
# Parsing file: ../dataset/Windows/wrd9554.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:21.253261]
#
# Parsing wrd9148.txt
# Parsing file: ../dataset/Windows/wrd9148.txt
# Total size after encoding is 99995 100000
# Parsing done. [Time taken: 0:00:20.545904]
#
# Parsing wrd9342.txt
# Parsing file: ../dataset/Windows/wrd9342.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:21.215060]
#
# Parsing wrd9133.txt
# Parsing file: ../dataset/Windows/wrd9133.txt
# Total size after encoding is 99989 100000
# Parsing done. [Time taken: 0:00:21.203557]
#
# Parsing wrd990138.txt
# Parsing file: ../dataset/Windows/wrd990138.txt
# Total size after encoding is 99984 100000
# Parsing done. [Time taken: 0:00:20.476085]
#
# Parsing wrd9759.txt
# Parsing file: ../dataset/Windows/wrd9759.txt
# Total size after encoding is 99960 100000
# Parsing done. [Time taken: 0:00:21.300861]
#
# Parsing wrd9066.txt
# Parsing file: ../dataset/Windows/wrd9066.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.540244]
#
# Parsing wrd990034.txt
# Parsing file: ../dataset/Windows/wrd990034.txt
# Total size after encoding is 99977 100000
# Parsing done. [Time taken: 0:00:20.662844]
#
# Parsing wrd9835.txt
# Parsing file: ../dataset/Windows/wrd9835.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:21.228606]
#
# Parsing wrd9077.txt
# Parsing file: ../dataset/Windows/wrd9077.txt
# Total size after encoding is 99950 100000
# Parsing done. [Time taken: 0:00:20.737725]
#
# Parsing wrd9139.txt
# Parsing file: ../dataset/Windows/wrd9139.txt
# Total size after encoding is 99985 100000
# Parsing done. [Time taken: 0:00:20.792449]
#
# Parsing wrd990030.txt
# Parsing file: ../dataset/Windows/wrd990030.txt
# Total size after encoding is 99968 100000
# Parsing done. [Time taken: 0:00:21.086149]
#
# Parsing wrd86.txt
# Parsing file: ../dataset/Windows/wrd86.txt
# Total size after encoding is 99948 100000
# Parsing done. [Time taken: 0:00:20.742517]
#
# Parsing wrd9866.txt
# Parsing file: ../dataset/Windows/wrd9866.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:20.559542]
#
# Parsing wrd9234.txt
# Parsing file: ../dataset/Windows/wrd9234.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.764410]
#
# Parsing wrd9290.txt
# Parsing file: ../dataset/Windows/wrd9290.txt
# Total size after encoding is 99984 100000
# Parsing done. [Time taken: 0:00:20.592826]
#
# Parsing wrd9415.txt
# Parsing file: ../dataset/Windows/wrd9415.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.321353]
#
# Parsing wrd20.txt
# Parsing file: ../dataset/Windows/wrd20.txt
# Total size after encoding is 99983 100000
# Parsing done. [Time taken: 0:00:21.419492]
#
# Parsing wrd9857.txt
# Parsing file: ../dataset/Windows/wrd9857.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:20.703509]
#
# Parsing wrd9891.txt
# Parsing file: ../dataset/Windows/wrd9891.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:20.564499]
#
# Parsing wrd81.txt
# Parsing file: ../dataset/Windows/wrd81.txt
# Total size after encoding is 99942 100000
# Parsing done. [Time taken: 0:00:21.302955]
#
# Parsing wrd9382.txt
# Parsing file: ../dataset/Windows/wrd9382.txt
# Total size after encoding is 99971 100000
# Parsing done. [Time taken: 0:00:20.679097]
#
# Parsing wrd9264.txt
# Parsing file: ../dataset/Windows/wrd9264.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:21.004644]
#
# Parsing wrd9800.txt
# Parsing file: ../dataset/Windows/wrd9800.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:20.915653]
#
# Parsing wrd9727.txt
# Parsing file: ../dataset/Windows/wrd9727.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:20.769531]
#
# Parsing wrd9288.txt
# Parsing file: ../dataset/Windows/wrd9288.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:21.003974]
#
# Parsing wrd9674.txt
# Parsing file: ../dataset/Windows/wrd9674.txt
# Total size after encoding is 99984 100000
# Parsing done. [Time taken: 0:00:21.003496]
#
# Parsing wrd14.txt
# Parsing file: ../dataset/Windows/wrd14.txt
# Total size after encoding is 99963 100000
# Parsing done. [Time taken: 0:00:20.740267]
#
# Parsing wrd9054.txt
# Parsing file: ../dataset/Windows/wrd9054.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.955636]
#
# Parsing wrd9005.txt
# Parsing file: ../dataset/Windows/wrd9005.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:21.221926]
#
# Parsing wrd9411.txt
# Parsing file: ../dataset/Windows/wrd9411.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.233998]
#
# Parsing wrd9689.txt
# Parsing file: ../dataset/Windows/wrd9689.txt
# Total size after encoding is 99994 100000
# Parsing done. [Time taken: 0:00:20.802638]
#
# Parsing wrd42.txt
# Parsing file: ../dataset/Windows/wrd42.txt
# Total size after encoding is 99965 100000
# Parsing done. [Time taken: 0:00:20.516837]
#
# Parsing wrd9831.txt
# Parsing file: ../dataset/Windows/wrd9831.txt
# Total size after encoding is 99994 100000
# Parsing done. [Time taken: 0:00:20.534827]
#
# Parsing wrd9717.txt
# Parsing file: ../dataset/Windows/wrd9717.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:21.227437]
#
# Parsing wrd9475.txt
# Parsing file: ../dataset/Windows/wrd9475.txt
# Total size after encoding is 99966 100000
# Parsing done. [Time taken: 0:00:20.951531]
#
# Parsing wrd9885.txt
# Parsing file: ../dataset/Windows/wrd9885.txt
# Total size after encoding is 99984 100000
# Parsing done. [Time taken: 0:00:20.690902]
#
# Parsing wrd990002.txt
# Parsing file: ../dataset/Windows/wrd990002.txt
# Total size after encoding is 99976 100000
# Parsing done. [Time taken: 0:00:21.237147]
#
# Parsing wrd9096.txt
# Parsing file: ../dataset/Windows/wrd9096.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.229736]
#
# Parsing wrd9128.txt
# Parsing file: ../dataset/Windows/wrd9128.txt
# Total size after encoding is 99987 100000
# Parsing done. [Time taken: 0:00:20.982210]
#
# Parsing wrd9074.txt
# Parsing file: ../dataset/Windows/wrd9074.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.701532]
#
# Parsing wrd9537.txt
# Parsing file: ../dataset/Windows/wrd9537.txt
# Total size after encoding is 99882 100000
# Parsing done. [Time taken: 0:00:20.698260]
#
# Parsing wrd9744.txt
# Parsing file: ../dataset/Windows/wrd9744.txt
# Total size after encoding is 99993 100000
# Parsing done. [Time taken: 0:00:20.749896]
#
# Parsing wrd9884.txt
# Parsing file: ../dataset/Windows/wrd9884.txt
# Total size after encoding is 99487 100237
# Parsing done. [Time taken: 0:00:22.005500]
#
# Parsing wrd990008.txt
# Parsing file: ../dataset/Windows/wrd990008.txt
# Total size after encoding is 99949 100000
# Parsing done. [Time taken: 0:00:20.776345]
#
# Parsing wrd9112.txt
# Parsing file: ../dataset/Windows/wrd9112.txt
# Total size after encoding is 99968 100000
# Parsing done. [Time taken: 0:00:21.023112]
#
# Parsing wrd9495.txt
# Parsing file: ../dataset/Windows/wrd9495.txt
# Total size after encoding is 99995 100000
# Parsing done. [Time taken: 0:00:20.475265]
#
# Parsing wrd990057.txt
# Parsing file: ../dataset/Windows/wrd990057.txt
# Total size after encoding is 99981 100000
# Parsing done. [Time taken: 0:00:20.899393]
#
# Parsing wrd9364.txt
# Parsing file: ../dataset/Windows/wrd9364.txt
# Total size after encoding is 99761 100000
# Parsing done. [Time taken: 0:00:20.835343]
#
# Parsing wrd9439.txt
# Parsing file: ../dataset/Windows/wrd9439.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:20.578980]
#
# Parsing wrd990007.txt
# Parsing file: ../dataset/Windows/wrd990007.txt
# Total size after encoding is 99968 100000
# Parsing done. [Time taken: 0:00:20.827426]
#
# Parsing wrd990076.txt
# Parsing file: ../dataset/Windows/wrd990076.txt
# Total size after encoding is 99976 100000
# Parsing done. [Time taken: 0:00:21.218376]
#
# Parsing wrd9786.txt
# Parsing file: ../dataset/Windows/wrd9786.txt
# Total size after encoding is 99994 100000
# Parsing done. [Time taken: 0:00:20.928520]
#
# Parsing wrd9704.txt
# Parsing file: ../dataset/Windows/wrd9704.txt
# Total size after encoding is 99965 100000
# Parsing done. [Time taken: 0:00:20.742394]
#
# Parsing wrd9513.txt
# Parsing file: ../dataset/Windows/wrd9513.txt
# Total size after encoding is 99928 100000
# Parsing done. [Time taken: 0:00:21.168022]
#
# Parsing wrd9204.txt
# Parsing file: ../dataset/Windows/wrd9204.txt
# Total size after encoding is 99987 100000
# Parsing done. [Time taken: 0:00:20.993178]
#
# Parsing wrd9875.txt
# Parsing file: ../dataset/Windows/wrd9875.txt
# Total size after encoding is 99872 100000
# Parsing done. [Time taken: 0:00:21.955620]
#
# Parsing wrd990093.txt
# Parsing file: ../dataset/Windows/wrd990093.txt
# Total size after encoding is 99968 100000
# Parsing done. [Time taken: 0:00:21.045157]
#
# Parsing wrd9016.txt
# Parsing file: ../dataset/Windows/wrd9016.txt
# Total size after encoding is 99918 100000
# Parsing done. [Time taken: 0:00:21.162898]
#
# Parsing wrd9599.txt
# Parsing file: ../dataset/Windows/wrd9599.txt
# Total size after encoding is 99996 100000
# Parsing done. [Time taken: 0:00:20.738332]
#
# Parsing wrd990061.txt
# Parsing file: ../dataset/Windows/wrd990061.txt
# Total size after encoding is 99645 100000
# Parsing done. [Time taken: 0:00:23.300450]
#
# Parsing wrd990054.txt
# Parsing file: ../dataset/Windows/wrd990054.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:20.567902]
#
# Parsing wrd9277.txt
# Parsing file: ../dataset/Windows/wrd9277.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:20.991668]
#
# Parsing wrd9898.txt
# Parsing file: ../dataset/Windows/wrd9898.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:20.587609]
#
# Parsing wrd9407.txt
# Parsing file: ../dataset/Windows/wrd9407.txt
# Total size after encoding is 99928 100000
# Parsing done. [Time taken: 0:00:20.257081]
#
# Parsing wrd9654.txt
# Parsing file: ../dataset/Windows/wrd9654.txt
# Total size after encoding is 99990 100000
# Parsing done. [Time taken: 0:00:21.037419]
#
# Parsing wrd9157.txt
# Parsing file: ../dataset/Windows/wrd9157.txt
# Total size after encoding is 99946 100000
# Parsing done. [Time taken: 0:00:20.970320]
#
# Parsing wrd9834.txt
# Parsing file: ../dataset/Windows/wrd9834.txt
# Total size after encoding is 99929 100000
# Parsing done. [Time taken: 0:00:20.905383]
#
# Parsing wrd9887.txt
# Parsing file: ../dataset/Windows/wrd9887.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:21.011211]
#
# Parsing wrd9758.txt
# Parsing file: ../dataset/Windows/wrd9758.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:20.768787]
#
# Parsing wrd9331.txt
# Parsing file: ../dataset/Windows/wrd9331.txt
# Total size after encoding is 99987 100000
# Parsing done. [Time taken: 0:00:20.594477]
#
# Parsing wrd990015.txt
# Parsing file: ../dataset/Windows/wrd990015.txt
# Total size after encoding is 99971 100000
# Parsing done. [Time taken: 0:00:21.081795]
#
# Parsing wrd9080.txt
# Parsing file: ../dataset/Windows/wrd9080.txt
# Total size after encoding is 99956 100000
# Parsing done. [Time taken: 0:00:20.733477]
#
# Parsing wrd9262.txt
# Parsing file: ../dataset/Windows/wrd9262.txt
# Total size after encoding is 99993 100000
# Parsing done. [Time taken: 0:00:20.774725]
#
# Parsing wrd9202.txt
# Parsing file: ../dataset/Windows/wrd9202.txt
# Total size after encoding is 99955 100000
# Parsing done. [Time taken: 0:00:21.288074]
#
# Parsing wrd9867.txt
# Parsing file: ../dataset/Windows/wrd9867.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:20.915033]
#
# Parsing wrd9237.txt
# Parsing file: ../dataset/Windows/wrd9237.txt
# Total size after encoding is 99933 100000
# Parsing done. [Time taken: 0:00:21.261419]
#
# Parsing wrd9570.txt
# Parsing file: ../dataset/Windows/wrd9570.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.750386]
#
# Parsing wrd9176.txt
# Parsing file: ../dataset/Windows/wrd9176.txt
# Total size after encoding is 99915 100000
# Parsing done. [Time taken: 0:00:21.605406]
#
# Parsing wrd9477.txt
# Parsing file: ../dataset/Windows/wrd9477.txt
# Total size after encoding is 99989 100000
# Parsing done. [Time taken: 0:00:20.761905]
#
# Parsing wrd9889.txt
# Parsing file: ../dataset/Windows/wrd9889.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:21.228672]
#
# Parsing wrd9788.txt
# Parsing file: ../dataset/Windows/wrd9788.txt
# Total size after encoding is 99966 100000
# Parsing done. [Time taken: 0:00:20.938546]
#
# Parsing wrd9255.txt
# Parsing file: ../dataset/Windows/wrd9255.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:20.818275]
#
# Parsing wrd990049.txt
# Parsing file: ../dataset/Windows/wrd990049.txt
# Total size after encoding is 99967 100000
# Parsing done. [Time taken: 0:00:20.793620]
#
# Parsing wrd9231.txt
# Parsing file: ../dataset/Windows/wrd9231.txt
# Total size after encoding is 99905 100000
# Parsing done. [Time taken: 0:00:22.456588]
#
# Parsing wrd9356.txt
# Parsing file: ../dataset/Windows/wrd9356.txt
# Total size after encoding is 99919 100000
# Parsing done. [Time taken: 0:00:22.728452]
#
# Parsing wrd21.txt
# Parsing file: ../dataset/Windows/wrd21.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:20.540830]
#
# Parsing wrd9057.txt
# Parsing file: ../dataset/Windows/wrd9057.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.507793]
#
# Parsing wrd9079.txt
# Parsing file: ../dataset/Windows/wrd9079.txt
# Total size after encoding is 99983 100000
# Parsing done. [Time taken: 0:00:21.035629]
#
# Parsing wrd53.txt
# Parsing file: ../dataset/Windows/wrd53.txt
# Total size after encoding is 99964 100000
# Parsing done. [Time taken: 0:00:20.925209]
#
# Parsing wrd9521.txt
# Parsing file: ../dataset/Windows/wrd9521.txt
# Total size after encoding is 99950 100000
# Parsing done. [Time taken: 0:00:20.942006]
#
# Parsing wrd9850.txt
# Parsing file: ../dataset/Windows/wrd9850.txt
# Total size after encoding is 99955 100000
# Parsing done. [Time taken: 0:00:21.306088]
#
# Parsing wrd9097.txt
# Parsing file: ../dataset/Windows/wrd9097.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.081664]
#
# Parsing wrd9336.txt
# Parsing file: ../dataset/Windows/wrd9336.txt
# Total size after encoding is 99974 100000
# Parsing done. [Time taken: 0:00:20.697473]
#
# Parsing wrd9530.txt
# Parsing file: ../dataset/Windows/wrd9530.txt
# Total size after encoding is 99980 100000
# Parsing done. [Time taken: 0:00:21.009598]
#
# Parsing wrd9067.txt
# Parsing file: ../dataset/Windows/wrd9067.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.342627]
#
# Parsing wrd9585.txt
# Parsing file: ../dataset/Windows/wrd9585.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:20.768317]
#
# Parsing wrd9125.txt
# Parsing file: ../dataset/Windows/wrd9125.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:21.017429]
#
# Parsing wrd990000.txt
# Parsing file: ../dataset/Windows/wrd990000.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:20.706778]
#
# Parsing wrd83.txt
# Parsing file: ../dataset/Windows/wrd83.txt
# Total size after encoding is 99797 100000
# Parsing done. [Time taken: 0:00:21.284012]
#
# Parsing wrd9785.txt
# Parsing file: ../dataset/Windows/wrd9785.txt
# Total size after encoding is 99988 100000
# Parsing done. [Time taken: 0:00:21.029594]
#
# Parsing wrd9185.txt
# Parsing file: ../dataset/Windows/wrd9185.txt
# Total size after encoding is 99958 100000
# Parsing done. [Time taken: 0:00:20.670309]
#
# Parsing wrd00.txt
# Parsing file: ../dataset/Windows/wrd00.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:22.724953]
#
# Parsing wrd9648.txt
# Parsing file: ../dataset/Windows/wrd9648.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:20.817781]
#
# Parsing wrd9504.txt
# Parsing file: ../dataset/Windows/wrd9504.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:20.786314]
#
# Parsing wrd9522.txt
# Parsing file: ../dataset/Windows/wrd9522.txt
# Total size after encoding is 99998 100000
# Parsing done. [Time taken: 0:00:21.191744]
#
# Parsing wrd9236.txt
# Parsing file: ../dataset/Windows/wrd9236.txt
# Total size after encoding is 99929 100000
# Parsing done. [Time taken: 0:00:20.463628]
#
# Parsing wrd9684.txt
# Parsing file: ../dataset/Windows/wrd9684.txt
# Total size after encoding is 99977 100000
# Parsing done. [Time taken: 0:00:20.794308]
#
# Parsing wrd9216.txt
# Parsing file: ../dataset/Windows/wrd9216.txt
# Total size after encoding is 99930 100000
# Parsing done. [Time taken: 0:00:20.759749]
#
# Parsing wrd9113.txt
# Parsing file: ../dataset/Windows/wrd9113.txt
# Total size after encoding is 99983 100000
# Parsing done. [Time taken: 0:00:20.498854]
#
# Parsing wrd9101.txt
# Parsing file: ../dataset/Windows/wrd9101.txt
# Total size after encoding is 99948 100000
# Parsing done. [Time taken: 0:00:20.965345]
#
# Parsing wrd9730.txt
# Parsing file: ../dataset/Windows/wrd9730.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:21.316325]
#
# Parsing wrd9317.txt
# Parsing file: ../dataset/Windows/wrd9317.txt
# Total size after encoding is 99977 100000
# Parsing done. [Time taken: 0:00:20.580023]
#
# Parsing wrd9552.txt
# Parsing file: ../dataset/Windows/wrd9552.txt
# Total size after encoding is 99974 100000
# Parsing done. [Time taken: 0:00:20.684702]
#
# Parsing wrd9677.txt
# Parsing file: ../dataset/Windows/wrd9677.txt
# Total size after encoding is 99994 100000
# Parsing done. [Time taken: 0:00:21.197651]
#
# Parsing wrd9322.txt
# Parsing file: ../dataset/Windows/wrd9322.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:20.938835]
#
# Parsing wrd990088.txt
# Parsing file: ../dataset/Windows/wrd990088.txt
# Total size after encoding is 99984 100000
# Parsing done. [Time taken: 0:00:20.474157]
#
# Parsing wrd22.txt
# Parsing file: ../dataset/Windows/wrd22.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:21.069665]
#
# Parsing wrd9894.txt
# Parsing file: ../dataset/Windows/wrd9894.txt
# Total size after encoding is 99943 100000
# Parsing done. [Time taken: 0:00:21.994997]
#
# Parsing wrd9852.txt
# Parsing file: ../dataset/Windows/wrd9852.txt
# Total size after encoding is 99961 100000
# Parsing done. [Time taken: 0:00:20.736586]
#
# Parsing wrd9652.txt
# Parsing file: ../dataset/Windows/wrd9652.txt
# Total size after encoding is 99876 100000
# Parsing done. [Time taken: 0:00:21.703474]
#
# Parsing wrd9036.txt
# Parsing file: ../dataset/Windows/wrd9036.txt
# Total size after encoding is 99949 100000
# Parsing done. [Time taken: 0:00:20.507090]
#
# Parsing wrd990131.txt
# Parsing file: ../dataset/Windows/wrd990131.txt
# Total size after encoding is 99959 100000
# Parsing done. [Time taken: 0:00:21.017072]
#
# Parsing wrd9069.txt
# Parsing file: ../dataset/Windows/wrd9069.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.191635]
#
# Parsing wrd9014.txt
# Parsing file: ../dataset/Windows/wrd9014.txt
# Total size after encoding is 99986 100000
# Parsing done. [Time taken: 0:00:21.434754]
#
# Parsing wrd69.txt
# Parsing file: ../dataset/Windows/wrd69.txt
# Total size after encoding is 99725 100000
# Parsing done. [Time taken: 0:00:21.572805]
#
# Parsing wrd9316.txt
# Parsing file: ../dataset/Windows/wrd9316.txt
# Total size after encoding is 99984 100000
# Parsing done. [Time taken: 0:00:20.314704]
#
# Parsing wrd9359.txt
# Parsing file: ../dataset/Windows/wrd9359.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.220269]
#
# Parsing wrd9804.txt
# Parsing file: ../dataset/Windows/wrd9804.txt
# Total size after encoding is 99729 100000
# Parsing done. [Time taken: 0:00:23.172741]
#
# Parsing wrd9000.txt
# Parsing file: ../dataset/Windows/wrd9000.txt
# Total size after encoding is 99957 100000
# Parsing done. [Time taken: 0:00:20.989432]
#
# Parsing wrd9388.txt
# Parsing file: ../dataset/Windows/wrd9388.txt
# Total size after encoding is 99983 100000
# Parsing done. [Time taken: 0:00:21.243470]
#
# Parsing wrd9410.txt
# Parsing file: ../dataset/Windows/wrd9410.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.891481]
#
# Parsing wrd990094.txt
# Parsing file: ../dataset/Windows/wrd990094.txt
# Total size after encoding is 99960 100000
# Parsing done. [Time taken: 0:00:20.756214]
#
# Parsing wrd9738.txt
# Parsing file: ../dataset/Windows/wrd9738.txt
# Total size after encoding is 99976 100000
# Parsing done. [Time taken: 0:00:20.797714]
#
# Parsing wrd9130.txt
# Parsing file: ../dataset/Windows/wrd9130.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.720090]
#
# Parsing wrd9345.txt
# Parsing file: ../dataset/Windows/wrd9345.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.254978]
#
# Parsing wrd9728.txt
# Parsing file: ../dataset/Windows/wrd9728.txt
# Total size after encoding is 99961 100000
# Parsing done. [Time taken: 0:00:20.789451]
#
# Parsing wrd9737.txt
# Parsing file: ../dataset/Windows/wrd9737.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:21.019742]
#
# Parsing wrd9864.txt
# Parsing file: ../dataset/Windows/wrd9864.txt
# Total size after encoding is 99603 100000
# Parsing done. [Time taken: 0:00:21.553807]
#
# Parsing wrd9486.txt
# Parsing file: ../dataset/Windows/wrd9486.txt
# Total size after encoding is 99977 100000
# Parsing done. [Time taken: 0:00:21.234847]
#
# Parsing wrd67.txt
# Parsing file: ../dataset/Windows/wrd67.txt
# Total size after encoding is 99662 100006
# Parsing done. [Time taken: 0:00:22.535688]
#
# Parsing wrd9291.txt
# Parsing file: ../dataset/Windows/wrd9291.txt
# Total size after encoding is 99950 100000
# Parsing done. [Time taken: 0:00:20.726427]
#
# Parsing wrd9428.txt
# Parsing file: ../dataset/Windows/wrd9428.txt
# Total size after encoding is 99995 100000
# Parsing done. [Time taken: 0:00:21.207910]
#
# Parsing wrd9011.txt
# Parsing file: ../dataset/Windows/wrd9011.txt
# Total size after encoding is 99959 100000
# Parsing done. [Time taken: 0:00:20.943414]
#
# Parsing wrd9273.txt
# Parsing file: ../dataset/Windows/wrd9273.txt
# Total size after encoding is 99981 100000
# Parsing done. [Time taken: 0:00:20.686425]
#
# Parsing wrd9401.txt
# Parsing file: ../dataset/Windows/wrd9401.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.794603]
#
# Parsing wrd9555.txt
# Parsing file: ../dataset/Windows/wrd9555.txt
# Total size after encoding is 99985 100000
# Parsing done. [Time taken: 0:00:20.654720]
#
# Parsing wrd9123.txt
# Parsing file: ../dataset/Windows/wrd9123.txt
# Total size after encoding is 99971 100000
# Parsing done. [Time taken: 0:00:20.740299]
#
# Parsing wrd9086.txt
# Parsing file: ../dataset/Windows/wrd9086.txt
# Total size after encoding is 99927 100000
# Parsing done. [Time taken: 0:00:22.537363]
#
# Parsing wrd9718.txt
# Parsing file: ../dataset/Windows/wrd9718.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:20.845075]
#
# Parsing wrd9848.txt
# Parsing file: ../dataset/Windows/wrd9848.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:20.558219]
#
# Parsing wrd9620.txt
# Parsing file: ../dataset/Windows/wrd9620.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:21.231809]
#
# Parsing wrd9365.txt
# Parsing file: ../dataset/Windows/wrd9365.txt
# Total size after encoding is 99995 100000
# Parsing done. [Time taken: 0:00:20.742770]
#
# Parsing wrd9200.txt
# Parsing file: ../dataset/Windows/wrd9200.txt
# Total size after encoding is 99962 100000
# Parsing done. [Time taken: 0:00:20.931769]
#
# Parsing wrd9229.txt
# Parsing file: ../dataset/Windows/wrd9229.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:21.171143]
#
# Parsing wrd9899.txt
# Parsing file: ../dataset/Windows/wrd9899.txt
# Total size after encoding is 99956 100000
# Parsing done. [Time taken: 0:00:20.795611]
#
# Parsing wrd990090.txt
# Parsing file: ../dataset/Windows/wrd990090.txt
# Total size after encoding is 99986 100000
# Parsing done. [Time taken: 0:00:20.927094]
#
# Parsing wrd87.txt
# Parsing file: ../dataset/Windows/wrd87.txt
# Total size after encoding is 99839 100000
# Parsing done. [Time taken: 0:00:21.011212]
#
# Parsing wrd9551.txt
# Parsing file: ../dataset/Windows/wrd9551.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:20.700741]
#
# Parsing wrd9116.txt
# Parsing file: ../dataset/Windows/wrd9116.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:21.030744]
#
# Parsing wrd9210.txt
# Parsing file: ../dataset/Windows/wrd9210.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:20.844468]
#
# Parsing wrd9681.txt
# Parsing file: ../dataset/Windows/wrd9681.txt
# Total size after encoding is 99980 100000
# Parsing done. [Time taken: 0:00:20.841070]
#
# Parsing wrd9089.txt
# Parsing file: ../dataset/Windows/wrd9089.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.594682]
#
# Parsing wrd66.txt
# Parsing file: ../dataset/Windows/wrd66.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:21.008501]
#
# Parsing wrd9735.txt
# Parsing file: ../dataset/Windows/wrd9735.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:20.716413]
#
# Parsing wrd9284.txt
# Parsing file: ../dataset/Windows/wrd9284.txt
# Total size after encoding is 99705 100001
# Parsing done. [Time taken: 0:00:23.035461]
#
# Parsing wrd9576.txt
# Parsing file: ../dataset/Windows/wrd9576.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.382744]
#
# Parsing wrd9799.txt
# Parsing file: ../dataset/Windows/wrd9799.txt
# Total size after encoding is 99947 100000
# Parsing done. [Time taken: 0:00:20.753554]
#
# Parsing wrd9653.txt
# Parsing file: ../dataset/Windows/wrd9653.txt
# Total size after encoding is 99996 100000
# Parsing done. [Time taken: 0:00:20.980294]
#
# Parsing wrd9485.txt
# Parsing file: ../dataset/Windows/wrd9485.txt
# Total size after encoding is 99983 100000
# Parsing done. [Time taken: 0:00:20.721712]
#
# Parsing wrd01.txt
# Parsing file: ../dataset/Windows/wrd01.txt
# Total size after encoding is 99988 100000
# Parsing done. [Time taken: 0:00:20.748884]
#
# Parsing wrd990086.txt
# Parsing file: ../dataset/Windows/wrd990086.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:21.018834]
#
# Parsing wrd9062.txt
# Parsing file: ../dataset/Windows/wrd9062.txt
# Total size after encoding is 99999 100000
# Parsing done. [Time taken: 0:00:20.823007]
#
# Parsing wrd9154.txt
# Parsing file: ../dataset/Windows/wrd9154.txt
# Total size after encoding is 99770 100000
# Parsing done. [Time taken: 0:00:21.294387]
#
# Parsing wrd9060.txt
# Parsing file: ../dataset/Windows/wrd9060.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.758083]
#
# Parsing wrd9206.txt
# Parsing file: ../dataset/Windows/wrd9206.txt
# Total size after encoding is 99989 100000
# Parsing done. [Time taken: 0:00:20.724895]
#
# Parsing wrd990100.txt
# Parsing file: ../dataset/Windows/wrd990100.txt
# Total size after encoding is 99989 100000
# Parsing done. [Time taken: 0:00:20.708848]
#
# Parsing wrd76.txt
# Parsing file: ../dataset/Windows/wrd76.txt
# Total size after encoding is 99748 100001
# Parsing done. [Time taken: 0:00:20.972526]
#
# Parsing wrd9318.txt
# Parsing file: ../dataset/Windows/wrd9318.txt
# Total size after encoding is 99949 100000
# Parsing done. [Time taken: 0:00:20.859981]
#
# Parsing wrd9269.txt
# Parsing file: ../dataset/Windows/wrd9269.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:21.264128]
#
# Parsing wrd9827.txt
# Parsing file: ../dataset/Windows/wrd9827.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:20.804408]
#
# Parsing wrd990075.txt
# Parsing file: ../dataset/Windows/wrd990075.txt
# Total size after encoding is 99951 100000
# Parsing done. [Time taken: 0:00:20.847595]
#
# Parsing wrd9296.txt
# Parsing file: ../dataset/Windows/wrd9296.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:20.799644]
#
# Parsing wrd9751.txt
# Parsing file: ../dataset/Windows/wrd9751.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:20.915939]
#
# Parsing wrd9690.txt
# Parsing file: ../dataset/Windows/wrd9690.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:20.785193]
#
# Parsing wrd9104.txt
# Parsing file: ../dataset/Windows/wrd9104.txt
# Total size after encoding is 99957 100000
# Parsing done. [Time taken: 0:00:21.234229]
#
# Parsing wrd78.txt
# Parsing file: ../dataset/Windows/wrd78.txt
# Total size after encoding is 99587 100000
# Parsing done. [Time taken: 0:00:22.318817]
#
# Parsing wrd9373.txt
# Parsing file: ../dataset/Windows/wrd9373.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:20.931693]
#
# Parsing wrd990082.txt
# Parsing file: ../dataset/Windows/wrd990082.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:21.031163]
#
# Parsing wrd9849.txt
# Parsing file: ../dataset/Windows/wrd9849.txt
# Total size after encoding is 99960 100000
# Parsing done. [Time taken: 0:00:20.745547]
#
# Parsing wrd9061.txt
# Parsing file: ../dataset/Windows/wrd9061.txt
# Total size after encoding is 99858 100003
# Parsing done. [Time taken: 0:00:21.087751]
#
# Parsing wrd9547.txt
# Parsing file: ../dataset/Windows/wrd9547.txt
# Total size after encoding is 99980 100000
# Parsing done. [Time taken: 0:00:21.292317]
#
# Parsing wrd9761.txt
# Parsing file: ../dataset/Windows/wrd9761.txt
# Total size after encoding is 99966 100000
# Parsing done. [Time taken: 0:00:20.724447]
#
# Parsing wrd9274.txt
# Parsing file: ../dataset/Windows/wrd9274.txt
# Total size after encoding is 99948 100000
# Parsing done. [Time taken: 0:00:20.760306]
#
# Parsing wrd9397.txt
# Parsing file: ../dataset/Windows/wrd9397.txt
# Total size after encoding is 99976 100000
# Parsing done. [Time taken: 0:00:20.793975]
#
# Parsing wrd9708.txt
# Parsing file: ../dataset/Windows/wrd9708.txt
# Total size after encoding is 99892 100000
# Parsing done. [Time taken: 0:00:21.468979]
#
# Parsing wrd9353.txt
# Parsing file: ../dataset/Windows/wrd9353.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.701106]
#
# Parsing wrd9452.txt
# Parsing file: ../dataset/Windows/wrd9452.txt
# Total size after encoding is 99974 100000
# Parsing done. [Time taken: 0:00:20.724236]
#
# Parsing wrd9607.txt
# Parsing file: ../dataset/Windows/wrd9607.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:20.716492]
#
# Parsing wrd9760.txt
# Parsing file: ../dataset/Windows/wrd9760.txt
# Total size after encoding is 99990 100000
# Parsing done. [Time taken: 0:00:21.197558]
#
# Parsing wrd9367.txt
# Parsing file: ../dataset/Windows/wrd9367.txt
# Total size after encoding is 99865 100000
# Parsing done. [Time taken: 0:00:22.264798]
#
# Parsing wrd36.txt
# Parsing file: ../dataset/Windows/wrd36.txt
# Total size after encoding is 99965 100000
# Parsing done. [Time taken: 0:00:20.926521]
#
# Parsing wrd9306.txt
# Parsing file: ../dataset/Windows/wrd9306.txt
# Total size after encoding is 99974 100000
# Parsing done. [Time taken: 0:00:21.004629]
#
# Parsing wrd9869.txt
# Parsing file: ../dataset/Windows/wrd9869.txt
# Total size after encoding is 99960 100000
# Parsing done. [Time taken: 0:00:20.756582]
#
# Parsing wrd9566.txt
# Parsing file: ../dataset/Windows/wrd9566.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.395797]
#
# Parsing wrd9503.txt
# Parsing file: ../dataset/Windows/wrd9503.txt
# Total size after encoding is 99971 100000
# Parsing done. [Time taken: 0:00:20.998871]
#
# Parsing wrd56.txt
# Parsing file: ../dataset/Windows/wrd56.txt
# Total size after encoding is 99980 100000
# Parsing done. [Time taken: 0:00:20.547896]
#
# Parsing wrd9358.txt
# Parsing file: ../dataset/Windows/wrd9358.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.255627]
#
# Parsing wrd9230.txt
# Parsing file: ../dataset/Windows/wrd9230.txt
# Total size after encoding is 99948 100000
# Parsing done. [Time taken: 0:00:21.473198]
#
# Parsing wrd9167.txt
# Parsing file: ../dataset/Windows/wrd9167.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:20.760457]
#
# Parsing wrd9542.txt
# Parsing file: ../dataset/Windows/wrd9542.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:21.011457]
#
# Parsing wrd9354.txt
# Parsing file: ../dataset/Windows/wrd9354.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.774465]
#
# Parsing wrd9733.txt
# Parsing file: ../dataset/Windows/wrd9733.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:20.725145]
#
# Parsing wrd990071.txt
# Parsing file: ../dataset/Windows/wrd990071.txt
# Total size after encoding is 99986 100000
# Parsing done. [Time taken: 0:00:20.528065]
#
# Parsing wrd990115.txt
# Parsing file: ../dataset/Windows/wrd990115.txt
# Total size after encoding is 99969 100000
# Parsing done. [Time taken: 0:00:21.234907]
#
# Parsing wrd9137.txt
# Parsing file: ../dataset/Windows/wrd9137.txt
# Total size after encoding is 99948 100000
# Parsing done. [Time taken: 0:00:20.858417]
#
# Parsing wrd9701.txt
# Parsing file: ../dataset/Windows/wrd9701.txt
# Total size after encoding is 99989 100000
# Parsing done. [Time taken: 0:00:21.019483]
#
# Parsing wrd9691.txt
# Parsing file: ../dataset/Windows/wrd9691.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:20.951189]
#
# Parsing wrd9249.txt
# Parsing file: ../dataset/Windows/wrd9249.txt
# Total size after encoding is 99983 100000
# Parsing done. [Time taken: 0:00:20.543479]
#
# Parsing wrd9218.txt
# Parsing file: ../dataset/Windows/wrd9218.txt
# Total size after encoding is 99896 100002
# Parsing done. [Time taken: 0:00:22.635149]
#
# Parsing wrd9703.txt
# Parsing file: ../dataset/Windows/wrd9703.txt
# Total size after encoding is 99988 100000
# Parsing done. [Time taken: 0:00:20.584218]
#
# Parsing wrd9263.txt
# Parsing file: ../dataset/Windows/wrd9263.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:20.495864]
#
# Parsing wrd9479.txt
# Parsing file: ../dataset/Windows/wrd9479.txt
# Total size after encoding is 99974 100000
# Parsing done. [Time taken: 0:00:21.035164]
#
# Parsing wrd9064.txt
# Parsing file: ../dataset/Windows/wrd9064.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.741136]
#
# Parsing wrd990101.txt
# Parsing file: ../dataset/Windows/wrd990101.txt
# Total size after encoding is 99981 100000
# Parsing done. [Time taken: 0:00:20.580361]
#
# Parsing wrd77.txt
# Parsing file: ../dataset/Windows/wrd77.txt
# Total size after encoding is 99954 100000
# Parsing done. [Time taken: 0:00:21.443993]
#
# Parsing wrd9789.txt
# Parsing file: ../dataset/Windows/wrd9789.txt
# Total size after encoding is 99963 100000
# Parsing done. [Time taken: 0:00:20.725642]
#
# Parsing wrd9151.txt
# Parsing file: ../dataset/Windows/wrd9151.txt
# Total size after encoding is 99958 100000
# Parsing done. [Time taken: 0:00:20.998543]
#
# Parsing wrd74.txt
# Parsing file: ../dataset/Windows/wrd74.txt
# Total size after encoding is 99318 100000
# ...
# Parsing file: ../dataset/Windows/wrd9420.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.326058]
#
# Parsing wrd17.txt
# Parsing file: ../dataset/Windows/wrd17.txt
# Total size after encoding is 99967 100000
# Parsing done. [Time taken: 0:00:21.193790]
#
# Parsing wrd9258.txt
# Parsing file: ../dataset/Windows/wrd9258.txt
# Total size after encoding is 99991 100000
# Parsing done. [Time taken: 0:00:20.519503]
#
# Parsing wrd9480.txt
# Parsing file: ../dataset/Windows/wrd9480.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:21.271883]
#
# Parsing wrd990033.txt
# Parsing file: ../dataset/Windows/wrd990033.txt
# Total size after encoding is 99984 100000
# Parsing done. [Time taken: 0:00:20.959174]
#
# Parsing wrd9038.txt
# Parsing file: ../dataset/Windows/wrd9038.txt
# Total size after encoding is 99937 100000
# Parsing done. [Time taken: 0:00:22.013607]
#
# Parsing wrd9856.txt
# Parsing file: ../dataset/Windows/wrd9856.txt
# Total size after encoding is 99993 100000
# Parsing done. [Time taken: 0:00:20.958631]
#
# Parsing wrd57.txt
# Parsing file: ../dataset/Windows/wrd57.txt
# Total size after encoding is 99419 100000
# Parsing done. [Time taken: 0:00:21.252539]
#
# Parsing wrd990051.txt
# Parsing file: ../dataset/Windows/wrd990051.txt
# Total size after encoding is 99784 100006
# Parsing done. [Time taken: 0:00:20.691794]
#
# Parsing wrd9010.txt
# Parsing file: ../dataset/Windows/wrd9010.txt
# Total size after encoding is 99988 100000
# Parsing done. [Time taken: 0:00:21.231854]
#
# Parsing wrd990133.txt
# Parsing file: ../dataset/Windows/wrd990133.txt
# Total size after encoding is 99968 100000
# Parsing done. [Time taken: 0:00:20.703870]
#
# Parsing wrd9297.txt
# Parsing file: ../dataset/Windows/wrd9297.txt
# Total size after encoding is 99909 100002
# Parsing done. [Time taken: 0:00:21.747958]
#
# Parsing wrd9371.txt
# Parsing file: ../dataset/Windows/wrd9371.txt
# Total size after encoding is 99967 100000
# Parsing done. [Time taken: 0:00:21.194275]
#
# Parsing wrd9343.txt
# Parsing file: ../dataset/Windows/wrd9343.txt
# Total size after encoding is 99983 100000
# Parsing done. [Time taken: 0:00:20.680509]
#
# Parsing wrd9166.txt
# Parsing file: ../dataset/Windows/wrd9166.txt
# Total size after encoding is 99948 100000
# Parsing done. [Time taken: 0:00:21.046327]
#
# Parsing wrd9020.txt
# Parsing file: ../dataset/Windows/wrd9020.txt
# Total size after encoding is 99943 100000
# Parsing done. [Time taken: 0:00:21.256726]
#
# Parsing wrd9103.txt
# Parsing file: ../dataset/Windows/wrd9103.txt
# Total size after encoding is 99974 100000
# Parsing done. [Time taken: 0:00:20.811932]
#
# Parsing wrd06.txt
# Parsing file: ../dataset/Windows/wrd06.txt
# Total size after encoding is 99980 100000
# Parsing done. [Time taken: 0:00:21.005103]
#
# Parsing wrd990089.txt
# Parsing file: ../dataset/Windows/wrd990089.txt
# Total size after encoding is 99955 100000
# Parsing done. [Time taken: 0:00:21.501812]
#
# Parsing wrd9518.txt
# Parsing file: ../dataset/Windows/wrd9518.txt
# Total size after encoding is 99975 100000
# Parsing done. [Time taken: 0:00:20.714935]
#
# Parsing wrd9120.txt
# Parsing file: ../dataset/Windows/wrd9120.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.285526]
#
# Parsing wrd9580.txt
# Parsing file: ../dataset/Windows/wrd9580.txt
# Total size after encoding is 99995 100000
# Parsing done. [Time taken: 0:00:20.882741]
#
# Parsing wrd31.txt
# Parsing file: ../dataset/Windows/wrd31.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:20.743163]
#
# Parsing wrd30.txt
# Parsing file: ../dataset/Windows/wrd30.txt
# Total size after encoding is 99994 100000
# Parsing done. [Time taken: 0:00:21.247230]
#
# Parsing wrd990103.txt
# Parsing file: ../dataset/Windows/wrd990103.txt
# Total size after encoding is 99951 100000
# Parsing done. [Time taken: 0:00:20.746858]
#
# Parsing wrd9233.txt
# Parsing file: ../dataset/Windows/wrd9233.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.264580]
#
# Parsing wrd9330.txt
# Parsing file: ../dataset/Windows/wrd9330.txt
# Total size after encoding is 99981 100000
# Parsing done. [Time taken: 0:00:21.233959]
#
# Parsing wrd9615.txt
# Parsing file: ../dataset/Windows/wrd9615.txt
# Total size after encoding is 99981 100000
# Parsing done. [Time taken: 0:00:21.041863]
#
# Parsing wrd9259.txt
# Parsing file: ../dataset/Windows/wrd9259.txt
# Total size after encoding is 99971 100000
# Parsing done. [Time taken: 0:00:20.641345]
#
# Parsing wrd9198.txt
# Parsing file: ../dataset/Windows/wrd9198.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:20.815817]
#
# Parsing wrd9268.txt
# Parsing file: ../dataset/Windows/wrd9268.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:20.587023]
#
# Parsing wrd9272.txt
# Parsing file: ../dataset/Windows/wrd9272.txt
# Total size after encoding is 99977 100000
# Parsing done. [Time taken: 0:00:20.673344]
#
# Parsing wrd9196.txt
# Parsing file: ../dataset/Windows/wrd9196.txt
# Total size after encoding is 99950 100000
# Parsing done. [Time taken: 0:00:21.262340]
#
# Parsing wrd9564.txt
# Parsing file: ../dataset/Windows/wrd9564.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.399165]
#
# Parsing wrd9134.txt
# Parsing file: ../dataset/Windows/wrd9134.txt
# Total size after encoding is 99971 100000
# Parsing done. [Time taken: 0:00:20.768308]
#
# Parsing wrd80.txt
# Parsing file: ../dataset/Windows/wrd80.txt
# Total size after encoding is 99227 100006
# Parsing done. [Time taken: 0:00:23.465469]
#
# Parsing wrd9808.txt
# Parsing file: ../dataset/Windows/wrd9808.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:20.723051]
#
# Parsing wrd9865.txt
# Parsing file: ../dataset/Windows/wrd9865.txt
# Total size after encoding is 99992 100000
# Parsing done. [Time taken: 0:00:20.926997]
#
# Parsing wrd990043.txt
# Parsing file: ../dataset/Windows/wrd990043.txt
# Total size after encoding is 99986 100000
# Parsing done. [Time taken: 0:00:21.237580]
#
# Parsing wrd9873.txt
# Parsing file: ../dataset/Windows/wrd9873.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:21.042689]
#
# Parsing wrd9088.txt
# Parsing file: ../dataset/Windows/wrd9088.txt
# Total size after encoding is 99847 100000
# Parsing done. [Time taken: 0:00:21.251088]
#
# Parsing wrd990055.txt
# Parsing file: ../dataset/Windows/wrd990055.txt
# Total size after encoding is 99968 100000
# Parsing done. [Time taken: 0:00:20.734179]
#
# Parsing wrd9523.txt
# Parsing file: ../dataset/Windows/wrd9523.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:20.758496]
#
# Parsing wrd9395.txt
# Parsing file: ../dataset/Windows/wrd9395.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:21.201585]
#
# Parsing wrd9035.txt
# Parsing file: ../dataset/Windows/wrd9035.txt
# Total size after encoding is 99959 100000
# Parsing done. [Time taken: 0:00:20.723837]
#
# Parsing wrd9228.txt
# Parsing file: ../dataset/Windows/wrd9228.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:20.710678]
#
# Parsing wrd9332.txt
# Parsing file: ../dataset/Windows/wrd9332.txt
# Total size after encoding is 99978 100000
# Parsing done. [Time taken: 0:00:21.269430]
#
# Parsing wrd43.txt
# Parsing file: ../dataset/Windows/wrd43.txt
# Total size after encoding is 99957 100000
# Parsing done. [Time taken: 0:00:20.795822]
#
# Parsing wrd9539.txt
# Parsing file: ../dataset/Windows/wrd9539.txt
# Total size after encoding is 99991 100000
# Parsing done. [Time taken: 0:00:20.788735]
#
# Parsing wrd9402.txt
# Parsing file: ../dataset/Windows/wrd9402.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.770411]
#
# Parsing wrd9182.txt
# Parsing file: ../dataset/Windows/wrd9182.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.273706]
#
# Parsing wrd9146.txt
# Parsing file: ../dataset/Windows/wrd9146.txt
# Total size after encoding is 99982 100000
# Parsing done. [Time taken: 0:00:20.968538]
#
# Parsing wrd9617.txt
# Parsing file: ../dataset/Windows/wrd9617.txt
# Total size after encoding is 99991 100000
# Parsing done. [Time taken: 0:00:21.395661]
#
# Parsing wrd9776.txt
# Parsing file: ../dataset/Windows/wrd9776.txt
# Total size after encoding is 99991 100000
# Parsing done. [Time taken: 0:00:20.990437]
#
# Parsing wrd9045.txt
# Parsing file: ../dataset/Windows/wrd9045.txt
# Total size after encoding is 99997 100000
# Parsing done. [Time taken: 0:00:20.771327]
#
# Parsing wrd9491.txt
# Parsing file: ../dataset/Windows/wrd9491.txt
# Total size after encoding is 99971 100000
# Parsing done. [Time taken: 0:00:21.214106]
#
# Parsing wrd9640.txt
# Parsing file: ../dataset/Windows/wrd9640.txt
# Total size after encoding is 99743 100000
# Parsing done. [Time taken: 0:00:21.496177]
#
# Parsing wrd990063.txt
# Parsing file: ../dataset/Windows/wrd990063.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:20.786705]
#
# Parsing wrd990012.txt
# Parsing file: ../dataset/Windows/wrd990012.txt
# Total size after encoding is 99977 100000
# Parsing done. [Time taken: 0:00:21.011511]
#
# Parsing wrd9747.txt
# Parsing file: ../dataset/Windows/wrd9747.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:20.930096]
#
# Parsing wrd9376.txt
# Parsing file: ../dataset/Windows/wrd9376.txt
# Total size after encoding is 99972 100000
# Parsing done. [Time taken: 0:00:21.250723]
#
# Parsing wrd18.txt
# Parsing file: ../dataset/Windows/wrd18.txt
# Total size after encoding is 99991 100000
# Parsing done. [Time taken: 0:00:20.723907]
#
# Parsing wrd9058.txt
# Parsing file: ../dataset/Windows/wrd9058.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.661712]
#
# Parsing wrd990087.txt
# Parsing file: ../dataset/Windows/wrd990087.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:21.306018]
#
# Parsing wrd9467.txt
# Parsing file: ../dataset/Windows/wrd9467.txt
# Total size after encoding is 99985 100000
# Parsing done. [Time taken: 0:00:20.321947]
#
# Parsing wrd9669.txt
# Parsing file: ../dataset/Windows/wrd9669.txt
# Total size after encoding is 99964 100000
# Parsing done. [Time taken: 0:00:20.928772]
#
# Parsing wrd9604.txt
# Parsing file: ../dataset/Windows/wrd9604.txt
# Total size after encoding is 99942 100000
# Parsing done. [Time taken: 0:00:21.047003]
#
# Parsing wrd9362.txt
# Parsing file: ../dataset/Windows/wrd9362.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.281702]
#
# Parsing wrd9603.txt
# Parsing file: ../dataset/Windows/wrd9603.txt
# Total size after encoding is 99981 100000
# Parsing done. [Time taken: 0:00:20.924319]
#
# Parsing wrd990143.txt
# Parsing file: ../dataset/Windows/wrd990143.txt
# Total size after encoding is 99968 100000
# Parsing done. [Time taken: 0:00:21.022063]
#
# Parsing wrd990066.txt
# Parsing file: ../dataset/Windows/wrd990066.txt
# Total size after encoding is 99963 100000
# Parsing done. [Time taken: 0:00:20.932126]
#
# Parsing wrd990129.txt
# Parsing file: ../dataset/Windows/wrd990129.txt
# Total size after encoding is 99973 100000
# Parsing done. [Time taken: 0:00:20.757613]
#
# Parsing wrd9793.txt
# Parsing file: ../dataset/Windows/wrd9793.txt
# Total size after encoding is 99991 100000
# Parsing done. [Time taken: 0:00:21.170734]
#
# Parsing wrd9257.txt
# Parsing file: ../dataset/Windows/wrd9257.txt
# Total size after encoding is 99963 100000
# Parsing done. [Time taken: 0:00:21.030464]
#
# Parsing wrd990024.txt
# Parsing file: ../dataset/Windows/wrd990024.txt
# Total size after encoding is 99990 100000
# Parsing done. [Time taken: 0:00:20.742409]
#
# Parsing wrd9561.txt
# Parsing file: ../dataset/Windows/wrd9561.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.914732]
#
# Parsing wrd52.txt
# Parsing file: ../dataset/Windows/wrd52.txt
# Total size after encoding is 99968 100000
# Parsing done. [Time taken: 0:00:20.766549]
#
# Parsing wrd9075.txt
# Parsing file: ../dataset/Windows/wrd9075.txt
# Total size after encoding is 99956 100000
# Parsing done. [Time taken: 0:00:21.421569]
#
# Parsing wrd9416.txt
# Parsing file: ../dataset/Windows/wrd9416.txt
# Total size after encoding is 99996 100000
# Parsing done. [Time taken: 0:00:20.786351]
#
# Parsing wrd9381.txt
# Parsing file: ../dataset/Windows/wrd9381.txt
# Total size after encoding is 99985 100000
# Parsing done. [Time taken: 0:00:20.578029]
#
# Parsing wrd26.txt
# Parsing file: ../dataset/Windows/wrd26.txt
# Total size after encoding is 99960 100000
# Parsing done. [Time taken: 0:00:20.744453]
#
# Parsing wrd9678.txt
# Parsing file: ../dataset/Windows/wrd9678.txt
# Total size after encoding is 99970 100000
# Parsing done. [Time taken: 0:00:20.994076]
#
# Parsing wrd28.txt
# Parsing file: ../dataset/Windows/wrd28.txt
# Total size after encoding is 99754 100001
# Parsing done. [Time taken: 0:00:21.465519]
#
# Parsing wrd9072.txt
# Parsing file: ../dataset/Windows/wrd9072.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.765092]
#
# Parsing wrd9065.txt
# Parsing file: ../dataset/Windows/wrd9065.txt
# Total size after encoding is 100000 100000
# Parsing done. [Time taken: 0:00:20.687027]
#
# Parsing wrd9012.txt
# Parsing file: ../dataset/Windows/wrd9012.txt
# Total size after encoding is 99942 100000
# Parsing done. [Time taken: 0:00:21.278704]
#
# Parsing wrd990044.txt
# Parsing file: ../dataset/Windows/wrd990044.txt
# Total size after encoding is 99979 100000
# Parsing done. [Time taken: 0:00:21.226591]
#
# Parsing wrd9560.txt
# Parsing file: ../dataset/Windows/wrd9560.txt
# Total size after encoding is 99791 100002
# Processed 12.0% of log lines.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18752/3353197452.py in <module>
#      50 for file in file_list:
#      51     print("\nParsing", file)
# ---> 52     parse_log(data_dir, output_dir, file, parser_type)
#      53
#      54
#
# /tmp/ipykernel_18752/1019917905.py in parse_log(input_dir, output_dir, log_file, parser_type)
#      22                                  rex=regex,
#      23                                  keep_para=keep_para, maxChild=1000)
# ---> 24         parser.parse(log_file)
#      25
#      26     elif parser_type == "spell":
#
# ~/W266/logparser/Drain.py in parse(self, logName)
#     253
#     254         count = 0
# --> 255         for idx, line in self.df_log.iterrows():
#     256
#     257             logID = line['LineId']
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in iterrows(self)
#    1261         klass = self._constructor_sliced
#    1262         for k, v in zip(self.index, self.values):
# -> 1263             s = klass(v, index=columns, name=k)
#    1264             yield k, s
#    1265
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     441                 manager = get_option("mode.data_manager")
#     442                 if manager == "block":
# --> 443                     data = SingleBlockManager.from_array(data, index)
#     444                 elif manager == "array":
#     445                     data = SingleArrayManager.from_array(data, index)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1572         Constructor for if we have an array that is not yet a Block.
#    1573         """
# -> 1574         block = new_block(array, placement=slice(0, len(index)), ndim=1)
#    1575         return cls(block, index)
#    1576
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/internals/blocks.py in new_block(values, placement, ndim, klass)
#    1938
#    1939     if klass is None:
# -> 1940         klass = get_block_type(values, values.dtype)
#    1941
#    1942     values = maybe_coerce_values(values)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    1903     # We use vtype and kind checks because they are much more performant
#    1904     #  than is_foo_dtype
# -> 1905     dtype = cast(np.dtype, pandas_dtype(dtype) if dtype else values.dtype)
#    1906     vtype = dtype.type
#    1907     kind = dtype.kind
#
# /opt/conda/lib/python3.7/typing.py in cast(typ, val)
#     896
#     897
# --> 898 def cast(typ, val):
#     899     """Cast a value to a type.
#     900
#
# KeyboardInterrupt:

# %%
##File parser

data_dir = os.path.expanduser("../dataset/Windows")
output_dir = "../output/windows/"
raw_log_file = "xaa.txt"
sample_log_file = "xaa.txt"
sample_window_size = 2*10**7
sample_step_size = 10**4
window_name = ''
log_file = sample_log_file

parser_type = 'drain'
#mins
window_size = 1
step_size = 0.5
train_ratio = 6000

hresult_dict = {'0x00000000': 1,'0x800f080d':2,'0x800f0805':3, '0x80070490':4, '0x80004005':5, '0x80070001':6, '0x80071a2d':7, '0x80070216':8, '0x80070bc2':9, '0x800f0816':10, '0x800f0806':11, '0x800f0902':12, '0x80070002':13, '0x80070013':14}

def matchfunc(line):
    # Capture one-or-more characters of non-whitespace after the initial match
    match = re.search(r'HRESULT = (\S+)', line)

    # Did we find a match?
    if match:
        # Yes, process it
        weather = match.group(1)
        return(hresult_dict[weather])
    return(0)

########
# count anomaly
########
# count_anomaly(data_dir + log_file)
# sys.exit()

import glob

a = glob.glob(output_dir +"/*_structured.csv") 
file_list=[os.path.basename(list_item) for list_item in a]

#print(file_list)


##################
# Transformation #
##################
for file in file_list:
    print("\nTransforming", file)
    df = pd.read_csv(f'{output_dir}{file}')
    df['Label'] = 0

    #df.loc[df['Content'].str.contains("HRESULT"), "Label"] = 1
    df['Label'] = df.apply(lambda row: matchfunc(row['Content']), axis = 1)
    df.to_excel(f'{output_dir}{file}_labeled.xlsx')  
    



# csv files in the path
file_list = glob.glob(output_dir + "*_labeled.xlsx")
 
# list of excel files we want to merge.
# pd.read_excel(file_path) reads the excel
# data into pandas dataframe.
excl_list = []
 
for file in file_list:
    excl_list.append(pd.read_excel(file))
 
# create a new dataframe to store the
# merged excel file.
excl_merged = pd.DataFrame()
 
for excl_file in excl_list:
     
    # appends the data into the excl_merged
    # dataframe.
    excl_merged = excl_merged.append(
      excl_file, ignore_index=True)
 
# exports the dataframe into excel file with
# specified name.
excl_merged.to_csv('total_output.csv', index=False)
print("done!!")
# Out:
# Transforming wrd9362.txt_structured.csv
#
# Transforming wrd990006.txt_structured.csv
#
# Transforming wrd56.txt_structured.csv
#
# Transforming wrd990138.txt_structured.csv
#
# Transforming wrd9856.txt_structured.csv
#
# Transforming wrd9583.txt_structured.csv
#
# Transforming wrd9035.txt_structured.csv
#
# Transforming wrd9542.txt_structured.csv
#
# Transforming wrd9141.txt_structured.csv
#
# Transforming wrd9437.txt_structured.csv
#
# Transforming wrd9198.txt_structured.csv
#
# Transforming wrd78.txt_structured.csv
#
# Transforming wrd9835.txt_structured.csv
#
# Transforming wrd9781.txt_structured.csv
#
# Transforming wrd9134.txt_structured.csv
#
# Transforming wrd990071.txt_structured.csv
#
# Transforming wrd9137.txt_structured.csv
#
# Transforming wrd9240.txt_structured.csv
#
# Transforming wrd14.txt_structured.csv
#
# Transforming wrd9089.txt_structured.csv
#
# Transforming wrd9576.txt_structured.csv
#
# Transforming wrd9479.txt_structured.csv
#
# Transforming wrd9581.txt_structured.csv
#
# Transforming wrd9486.txt_structured.csv
#
# Transforming wrd9273.txt_structured.csv
#
# Transforming wrd9832.txt_structured.csv
#
# Transforming wrd9884.txt_structured.csv
#
# Transforming wrd69.txt_structured.csv
#
# Transforming wrd990128.txt_structured.csv
#
# Transforming wrd9353.txt_structured.csv
#
# Transforming wrd9000.txt_structured.csv
#
# Transforming wrd9800.txt_structured.csv
#
# Transforming wrd9769.txt_structured.csv
#
# Transforming wrd9258.txt_structured.csv
#
# Transforming wrd990000.txt_structured.csv
#
# Transforming wrd9807.txt_structured.csv
#
# Transforming wrd9274.txt_structured.csv
#
# Transforming wrd9603.txt_structured.csv
#
# Transforming wrd9808.txt_structured.csv
#
# Transforming wrd9620.txt_structured.csv
#
# Transforming wrd9291.txt_structured.csv
#
# Transforming wrd9624.txt_structured.csv
#
# Transforming wrd9564.txt_structured.csv
#
# Transforming wrd9061.txt_structured.csv
#
# Transforming wrd9005.txt_structured.csv
#
# Transforming wrd990143.txt_structured.csv
#
# Transforming wrd21.txt_structured.csv
#
# Transforming wrd9865.txt_structured.csv
#
# Transforming wrd9060.txt_structured.csv
#
# Transforming wrd990088.txt_structured.csv
#
# Transforming wrd9852.txt_structured.csv
#
# Transforming wrd9166.txt_structured.csv
#
# Transforming wrd9631.txt_structured.csv
#
# Transforming wrd9338.txt_structured.csv
#
# Transforming wrd9679.txt_structured.csv
#
# Transforming wrd990043.txt_structured.csv
#
# Transforming wrd9388.txt_structured.csv
#
# Transforming wrd9541.txt_structured.csv
#
# Transforming wrd9277.txt_structured.csv
#
# Transforming wrd990066.txt_structured.csv
#
# Transforming wrd9890.txt_structured.csv
#
# Transforming wrd9606.txt_structured.csv
#
# Transforming wrd76.txt_structured.csv
#
# Transforming wrd990140.txt_structured.csv
#
# Transforming wrd9862.txt_structured.csv
#
# Transforming wrd9364.txt_structured.csv
#
# Transforming wrd9041.txt_structured.csv
#
# Transforming wrd9382.txt_structured.csv
#
# Transforming wrd9249.txt_structured.csv
#
# Transforming wrd9132.txt_structured.csv
#
# Transforming wrd9204.txt_structured.csv
#
# Transforming wrd9504.txt_structured.csv
#
# Transforming wrd9402.txt_structured.csv
#
# Transforming wrd9656.txt_structured.csv
#
# Transforming wrd990086.txt_structured.csv
#
# Transforming wrd9262.txt_structured.csv
#
# Transforming wrd9875.txt_structured.csv
#
# Transforming wrd9072.txt_structured.csv
#
# Transforming wrd53.txt_structured.csv

# %%
import glob
file_list = glob.glob(data_dir +"/*.txt")
#########
# sample raw data
#########
#sample_raw_data(data_dir+raw_log_file, data_dir+sample_log_file, sample_window_size, sample_step_size )

a = glob.glob(data_dir +"/*.*") 
file_list=[os.path.basename(list_item) for list_item in a]
print(file_list)
##########
# Parser #
#########
for file in file_list:
    print("\nParsing", file)
    parse_log(data_dir, output_dir, file, parser_type)


##################
# Transformation #
##################
for file in file_list:
    print("\nTransforming", file)
    df = pd.read_csv(f'{output_dir}{file}_structured.csv')
    df['Label'] = 0

    #df.loc[df['Content'].str.contains("HRESULT"), "Label"] = 1
    df['Label'] = df.apply(lambda row: matchfunc(row['Content']), axis = 1)
    df.to_excel(f'{output_dir}{file}_labeled.xlsx')  
    



# csv files in the path
file_list = glob.glob(output_dir + "*_labeled.xlsx")
 
# list of excel files we want to merge.
# pd.read_excel(file_path) reads the excel
# data into pandas dataframe.
excl_list = []
 
for file in file_list:
    excl_list.append(pd.read_excel(file))
 
# create a new dataframe to store the
# merged excel file.
excl_merged = pd.DataFrame()
 
for excl_file in excl_list:
     
    # appends the data into the excl_merged
    # dataframe.
    excl_merged = excl_merged.append(
      excl_file, ignore_index=True)
 
# exports the dataframe into excel file with
# specified name.
excl_merged.to_csv('total_output.csv', index=False)
print("done!!")

# %%
# specifying the path to csv files
path = "C:/downloads"
 
# csv files in the path
file_list = glob.glob(path + "/*.xlsx")
 
# list of excel files we want to merge.
# pd.read_excel(file_path) reads the excel
# data into pandas dataframe.
excl_list = []
 
for file in file_list:
    excl_list.append(pd.read_excel(file))
 
# create a new dataframe to store the
# merged excel file.
excl_merged = pd.DataFrame()
 
for excl_file in excl_list:
     
    # appends the data into the excl_merged
    # dataframe.
    excl_merged = excl_merged.append(
      excl_file, ignore_index=True)
 
# exports the dataframe into excel file with
# specified name.
excl_merged.to_excel('total_food_sales.xlsx', index=False)
